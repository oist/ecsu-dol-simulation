# %%
import sys
import os
sys.path.insert(0,'../') # import project structure
from dol import plot, analyze_results
from dol.run_from_dir import run_simulation_from_dir

# %%
base_dir = '/bucket/FroeseU/fede/dol-simulation'
os.listdir(base_dir)
# Out:
# ['2n_exc-0.1', '2n_exc-0.1_rp-3_dual', '2n_exc-0.1_rp-3_switch']

# %%
exp_type = '2n_exc-0.1'
exp_dir = os.path.join(base_dir, exp_type)
analyze_results.get_last_performance_runs(exp_dir, print_values=False)
# Out:
# Selected evo: evo_2000.json
# DescribeResult(nobs=20, minmax=(array([0.70668667]), array([88.36715106])), mean=array([26.11399594]), variance=array([1579.73255489]), skewness=array([0.87672629]), kurtosis=array([-1.22582897]))

# %%
seed_dir = 'seed_002'
seed_exp_dir = os.path.join(base_dir, exp_type, seed_dir)

# %%
evo, sim, data_record_list = run_simulation_from_dir(
    dir=seed_exp_dir,
    generation=2000,
    genotype_idx=0,
    select_sim=0,
    write_data = False,
    random_target_seed = None,
    random_pairing_seed = None
)
# Out:
# Performace recomputed: 4999.1904728618365

# %%
select_sim = 0
data_record = data_record_list[select_sim]

# %%
plot.plot_performances(evo, log=True)

# %%
plot.plot_genotype_similarity(evo, sim)

# %%
plot.plot_data_scatter(data_record, 'agents_brain_output')

# %%
plot.plot_data_scatter(data_record, 'agents_brain_state')

# %%
trial = 'all'

# %%
plot.plot_data_time(data_record, 'agents_brain_input', trial)

# %%
plot.plot_data_time(data_record, 'agents_brain_output', trial)

# %%
plot.plot_data_time(data_record, 'agents_brain_state', trial)

# %%
plot.plot_data_time(data_record, 'agents_derivatives', trial)

# %%
plot.plot_motor_time(sim, data_record, 'agents_motors', trial)

# %%
plot.plot_data_time(data_record, 'tracker_wheels', trial)

# %%
plot.plot_data_time(data_record, 'tracker_velocity', trial)

# %%
plot.plot_data_time(data_record, 'tracker_signals', trial)

# %%
plot.plot_data_time(data_record, 'target_velocity', trial)

# %%
plot.plot_data_time_multi_keys(
    data_record, 
    keys=['tracker_position', 'target_position'], 
    title="Tracker and Target"
)

# %%
plot.plot_data_time(data_record, 'delta_tracker_target', trial)
